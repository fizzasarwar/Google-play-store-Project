# %% [markdown]
# # **Google Playstore Data Analytics**
#
# ---
#
#
# Dataset from Kaggle:[https://www.kaggle.com/gauthamp10/google-playstore-apps](https:/https://www.kaggle.com/gauthamp10/google-playstore-apps/)
# ---
# Name: Fizza Babri Sarwar

# %% [markdown]
# # **Introduction:**
#
# ---
#
#
# The Play Store apps data has enormous potential to drive app-making businesses to success. The dataset is chosen from Kaggle.The dataset consists of 10 million rows and 24 columns. We made sure that whatsoever machine learning algorithms we have studied, we implement all of them accordingly to the data.

# %% [markdown]
# # **Objective**
#
# ---
#
#
#
# The main objective of this project is to predict the rating of one app from 600k apps that app name is “ENGLISH”. We predict the rating on the basis of app features like app is free, category is entertainment.We apply multiple regression on it.

# %% [markdown]
# # **Insights:**
#
# 1:Total Apps name that is present on google playstore.
#
#
#
#
# 2:Count all categories according to genre.
#
#
#
# 3:Count and display all entertainment category.
#
#
#
#
# 4:Count and display all Music & Audio category.
#
#
# 5:Count and display all Education category.
#
#
#
# 6:Count and display all Book & Reference category.
#
#
#
# 7:Count and diplay all Personlaization Category.
#
#
#
# 8:Count the values of all Ratings in ascending order.
#
#
#
#
# 9:Count the values of Rating Count.
#
#
#
#
# 10:Count the values of Installs.
#
#
#
#
# 11:Count the free apps in dataset.
#
#
#
#
# 12:Count top 50 free app.
#
#
#
#
# 13:Show the values that how much apps are released in same date.
#
#
#
#
# 14:Show the values that how much apps are last updated in same date.
#
#
#
#
# 15:Show the content rating according to the genre.
#
#
#
# 16:Show top 20 content rating accoridng to the genre.
#
#
#
#
# 17:count the value and show that app is Add supported ot not.
#
#
#
#
# 18:show that how much app are in app purchase or not.
#
#
#
#
# 19:show the value of editor choice whether it is ture, false or not.
#
#
#
#
# 20:show the Installs according to the different categories.
#
#
#
#
# 21:Show top 30 apps name according to the install value.
#
#
# 22:show all the installs which is lesser than 100000000
#
# 23:Show top 20 categories accoridng to the Installs.
#
# 24:Show top 10 Installs according to the content Rating
# 25:Show all the categories according to the count
#
# 26:Show all the categories according to the rating
#
# ---

# %% [markdown]
# # **Imporitng Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## **Upload the Dataset(Getting the raw data):**

# %%
df = pd.read_csv("Google-Playstore.csv")
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:2718: DtypeWarning: Columns (8,20,21,22) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# # **Descriptive Analysis**

# %%
# Storing dataset into pandas dataframe
print("Dataset")
print("Rows and Columns", df.shape)
df
# Out:
# Dataset
# Rows and Columns (141714, 23)
#                                                  App Name  ... Editors Choice
# 0                                  HTTrack Website Copier  ...          False
# 1                           World War 2: Offline Strategy  ...          False
# 2                                                  WPSApp  ...          False
# 3       OfficeSuite - Office, PDF, Word, Excel, PowerP...  ...          False
# 4                                        Loud Player Free  ...          False
# ...                                                   ...  ...            ...
# 141709                    Psychology Facts For Life Hacks  ...          False
# 141710                            Learn Civil Engineering  ...          False
# 141711                             Learn Java Programming  ...          False
# 141712                   Free CV Maker & Resume PDF Maker  ...          False
# 141713                             SpeedVPN Trade Edition  ...            NaN
#
# [141714 rows x 23 columns]

# %%
#show the top 10 values
df.head(10)
# Out:
#                                             App Name  ... Editors Choice
# 0                             HTTrack Website Copier  ...          False
# 1                      World War 2: Offline Strategy  ...          False
# 2                                             WPSApp  ...          False
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...  ...          False
# 4                                   Loud Player Free  ...          False
# 5                                           eCharge+  ...          False
# 6  Jobonji: hire local pros handyman for odd jobs...  ...          False
# 7                          Little Panda’s Dream Town  ...          False
# 8                            Baby Panda: Dental Care  ...          False
# 9                                       Excel Reader  ...          False
#
# [10 rows x 23 columns]

# %%
#Show the last 10 values
df.tail(10)
# Out:
#                                 App Name  ... Editors Choice
# 141704        Belly Fat Weight Loss Diet  ...          False
# 141705                  Ramadan Pro 2018  ...          False
# 141706           Math games Brain Teaser  ...          False
# 141707               Learn C Programming  ...          False
# 141708  Inspirational Life Lesson Quotes  ...          False
# 141709   Psychology Facts For Life Hacks  ...          False
# 141710           Learn Civil Engineering  ...          False
# 141711            Learn Java Programming  ...          False
# 141712  Free CV Maker & Resume PDF Maker  ...          False
# 141713            SpeedVPN Trade Edition  ...            NaN
#
# [10 rows x 23 columns]

# %%
#type of dataframe
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#Show the Location of row no 10472
df.iloc[10472]
# Out:
# App Name                                   Truth or Dare, Cuddle Video
# App Id                                   video.chat.truthordare.cuddle
# Category                                                 Entertainment
# Rating                                                               0
# Rating Count                                                         0
# Installs                                                          100+
# Minimum Installs                                                   100
# Maximum Installs                                                   310
# Free                                                              True
# Price                                                                0
# Currency                                                           USD
# Size                                                               27M
# Minimum Android                                             4.1 and up
# Developer Id                                          Monkey Live Chat
# Developer Website                                                  NaN
# Developer Email                                 contact@cuddlelive.com
# Released                                                  Apr 15, 2020
# Last Updated                                              Apr 15, 2020
# Content Rating                                                Everyone
# Privacy Policy       https://www.cuddlelive.com/truthordare/privacy...
# Ad Supported                                                     False
# In App Purchases                                                 False
# Editors Choice                                                   False
# Name: 10472, dtype: object

# %%
#Slicing
df.iloc[10469:10472]
# Out:
#                                                 App Name  ... Editors Choice
# 10469                TopUp.com - Mobile Top Up Made Easy  ...          False
# 10470  Sudoku: Logic Number Puzzles, Fun& Free brain ...  ...          False
# 10471                RCC Beam Design - Civil Engineering  ...          False
#
# [3 rows x 23 columns]

# %%
#give all the info about all column
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 141714 entries, 0 to 141713
# Data columns (total 23 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   App Name           141714 non-null  object
#  1   App Id             141714 non-null  object
#  2   Category           141713 non-null  object
#  3   Rating             140298 non-null  float64
#  4   Rating Count       140298 non-null  float64
#  5   Installs           141630 non-null  object
#  6   Minimum Installs   141630 non-null  float64
#  7   Maximum Installs   141713 non-null  float64
#  8   Free               141713 non-null  object
#  9   Price              141713 non-null  float64
#  10  Currency           141630 non-null  object
#  11  Size               141713 non-null  object
#  12  Minimum Android    141415 non-null  object
#  13  Developer Id       141713 non-null  object
#  14  Developer Website  115386 non-null  object
#  15  Developer Email    141707 non-null  object
#  16  Released           140069 non-null  object
#  17  Last Updated       141713 non-null  object
#  18  Content Rating     141713 non-null  object
#  19  Privacy Policy     124900 non-null  object
#  20  Ad Supported       141713 non-null  object
#  21  In App Purchases   141713 non-null  object
#  22  Editors Choice     141713 non-null  object
# dtypes: float64(5), object(18)
# memory usage: 24.9+ MB

# %%
#gives the complete information about dataframe including five plot summary
df.describe(include ="all").T
# Out:
#                     count  unique  ...     75%          max
# App Name           141714  139433  ...     NaN          NaN
# App Id             141714  141714  ...     NaN          NaN
# Category           141713      48  ...     NaN          NaN
# Rating             140298     NaN  ...     4.5            5
# Rating Count       140298     NaN  ...     824  6.85071e+07
# Installs           141630      22  ...     NaN          NaN
# Minimum Installs   141630     NaN  ...  100000        1e+10
# Maximum Installs   141713     NaN  ...  107936  1.07727e+10
# Free               141713       2  ...     NaN          NaN
# Price              141713     NaN  ...       0          400
# Currency           141630      34  ...     NaN          NaN
# Size               141713    1328  ...     NaN          NaN
# Minimum Android    141415      54  ...     NaN          NaN
# Developer Id       141713   28535  ...     NaN          NaN
# Developer Website  115386   50099  ...     NaN          NaN
# Developer Email    141707   47043  ...     NaN          NaN
# Released           140069    3909  ...     NaN          NaN
# Last Updated       141713    3130  ...     NaN          NaN
# Content Rating     141713       6  ...     NaN          NaN
# Privacy Policy     124900   57893  ...     NaN          NaN
# Ad Supported       141713       2  ...     NaN          NaN
# In App Purchases   141713       2  ...     NaN          NaN
# Editors Choice     141713       2  ...     NaN          NaN
#
# [23 rows x 11 columns]

# %%
#show all column name
df.columns
# Out:
# Index(['App Name', 'App Id', 'Category', 'Rating', 'Rating Count', 'Installs',
#        'Minimum Installs', 'Maximum Installs', 'Free', 'Price', 'Currency',
#        'Size', 'Minimum Android', 'Developer Id', 'Developer Website',
#        'Developer Email', 'Released', 'Last Updated', 'Content Rating',
#        'Privacy Policy', 'Ad Supported', 'In App Purchases', 'Editors Choice'],
#       dtype='object')

# %% [markdown]
# # **Cleaning Of data**
#
# ---

# %% [markdown]
# We have raw data here so we need to clean that data we have many columns that are in garbage values, null values and missing values also we removed the extra columns that’s not needed for our project so we drop all these columns include . In the dataset app name we have one missing value then we filled it easily randomly.Categorical data is filled with mode and numerical columns fill this with mean . Install data is null  or data with “+”, “,” initially so we filled that or we can say we replace this with spaces.

# %%
#Shows all the null values of every column
df.isnull().sum()
# Out:
# App Name                 0
# App Id                   0
# Category                 1
# Rating                1416
# Rating Count          1416
# Installs                84
# Minimum Installs        84
# Maximum Installs         1
# Free                     1
# Price                    1
# Currency                84
# Size                     1
# Minimum Android        299
# Developer Id             1
# Developer Website    26328
# Developer Email          7
# Released              1645
# Last Updated             1
# Content Rating           1
# Privacy Policy       16814
# Ad Supported             1
# In App Purchases         1
# Editors Choice           1
# dtype: int64

# %%
#show the missing values through visulaization
sns.heatmap(df.isnull(),cmap = "GnBu_r")
plt.show()

# %%
#App Name description
df["App Name"].value_counts(dropna = False)
# Out:
# Solitaire                                           31
# Sudoku                                              26
# Spider Solitaire                                    25
# Word Search                                         21
# Mahjong                                             17
#                                                     ..
# Memopop - Memo, todo, check list                     1
# 新羅免税店                                                1
# Toy & Toons - Drop Blast & Match Toy Cubes Games     1
# Tests in Spanish                                     1
# VPP 2019                                             1
# Name: App Name, Length: 139433, dtype: int64

# %%
#null values of app name
df["App Name"].isnull().sum()
# Out:
# 0

# %%
#App name in ascending order
df.sort_values("App Name", ascending = True, inplace = False)
# Out:
#                                                 App Name  ... Editors Choice
# 114271                                           !nShelf  ...          False
# 60050                !نیم کلمه : بازی معمایی هیجان انگیز  ...          False
# 30824                                   "1C:Docflow" 2.1  ...          False
# 31218                 "Christmas Memory" - Matching Game  ...          False
# 79970        "Fancy" watch face pack 8 for Bubble Clouds  ...          False
# ...                                                  ...  ...            ...
# 96032            🧛‍♀️💄Vampire Girl Dress Up - Love Story  ...          False
# 96049   🧜‍♀️Mermaid Princess Makeup - Girl Fashion Salon  ...          False
# 87465                            🧠 Smart - Brain fitness  ...          False
# 100867                                🧨Heroes of Match 3  ...          False
# 19416       🧹🧽Mom's Sweet Helper - House Spring Cleaning  ...          False
#
# [141714 rows x 23 columns]

# %%
#App Id description
df["App Id"].value_counts(dropna = False)
# Out:
# world.easysolution.schoolbag             1
# br.com.beholdstudios.knightspp           1
# co.uk.twinkl.pudseyar                    1
# com.tomato.crossword.collection          1
# com.CountrysideGames.WestyWest           1
#                                         ..
# com.launcher.smart.koi.fish.theme        1
# free.call.international.phone.calling    1
# com.Gameberry.ColorCity                  1
# com.worksinc.bakkure2                    1
# com.adian.indiancricket                  1
# Name: App Id, Length: 141714, dtype: int64

# %%
df["App Id"].isnull().sum()
# Out:
# 0

# %%
#Category count acccording to genre
df["Category"].value_counts(dropna = False)
# Out:
# Education                  16183
# Books & Reference          12276
# Tools                       8914
# Music & Audio               8322
# Lifestyle                   6163
# Entertainment               6143
# Business                    6039
# Personalization             5687
# Health & Fitness            5117
# Puzzle                      4937
# Productivity                4745
# Finance                     4176
# Casual                      3611
# Travel & Local              3487
# Sports                      3177
# News & Magazines            2956
# Communication               2657
# Arcade                      2651
# Shopping                    2557
# Educational                 2494
# Social                      2413
# Medical                     2181
# Action                      2059
# Simulation                  2057
# Food & Drink                1679
# Adventure                   1634
# Word                        1606
# Role Playing                1509
# Photography                 1472
# Card                        1372
# Board                       1370
# Maps & Navigation           1192
# Strategy                    1109
# Video Players & Editors      921
# Trivia                       844
# Auto & Vehicles              754
# Weather                      737
# Racing                       663
# Art & Design                 575
# Dating                       513
# Casino                       464
# House & Home                 404
# Events                       392
# Parenting                    390
# Libraries & Demo             311
# Beauty                       310
# Music                        261
# Comics                       229
# NaN                            1
# Name: Category, dtype: int64

# %%
df["Category"].isnull().sum()
# Out:
# 1

# %%
#Count and display all education category.
df[df["Category"] == "Education"]
# Out:
#                                                  App Name  ... Editors Choice
# 105                                    Compass Calculator  ...          False
# 170                             PROTO - circuit simulator  ...          False
# 171                            Mechanics of Materials App  ...          False
# 185        Electrohelper - Electronics lab in your pocket  ...          False
# 186                                                Studyo  ...          False
# ...                                                   ...  ...            ...
# 141696  Clinical Dermatology (Skin Diseases and Treatm...  ...          False
# 141705                                   Ramadan Pro 2018  ...          False
# 141707                                Learn C Programming  ...          False
# 141710                            Learn Civil Engineering  ...          False
# 141711                             Learn Java Programming  ...          False
#
# [16183 rows x 23 columns]

# %%
#Count and display all Music and Audio category.

df[df["Category"] == "Music & Audio"]
# Out:
#                                                  App Name  ... Editors Choice
# 4                                        Loud Player Free  ...          False
# 20                             Loud Player - Audio player  ...          False
# 21      SoundSeeder -Play music simultaneously and in ...  ...          False
# 22                                      Fuel Music Player  ...          False
# 224                       RadioBox- Powered by ContentBox  ...          False
# ...                                                   ...  ...            ...
# 141695                             Wakokin Naziru M Ahmed  ...          False
# 141697                                 Wakokin Ado Gwanja  ...          False
# 141698              Al Shuraim Full Quran Read and Listen  ...          False
# 141700                           Wakokin Sarki Ado Bayero  ...          False
# 141701                   Al Sudais Full Quran Mp3 Offline  ...          False
#
# [8322 rows x 23 columns]

# %%
#Count and display all entertainment category.
df[df["Category"] == "Entertainment"]
# Out:
#                                                 App Name  ... Editors Choice
# 292                               Auraxis Control Center  ...          False
# 675         GhostTube Paranormal Investigation Simulator  ...          False
# 676     Ultimate Ghost Detector (real EMF, EVP recorder)  ...          False
# 682            China Radio 中国电台 中国收音机 中国广播电台 多国中文电台 华语电台  ...          False
# 717                                        Linear Art HD  ...          False
# ...                                                  ...  ...            ...
# 141318                   Dra. Ana Paula Barganian Casula  ...          False
# 141400                              Sling for AirTV Mini  ...          False
# 141588                                        Harmonizer  ...          False
# 141591                          Mygod Speech Synthesizer  ...          False
# 141596                                   Quotes Treasure  ...          False
#
# [6143 rows x 23 columns]

# %%
#Count and display all entertainment category.
df[df["Category"] == "Books & Reference"]
# Out:
#                                                  App Name  ... Editors Choice
# 26       All PDF - PDF Reader, PDF Viewer & PDF Converter  ...          False
# 514                                   Daily Readings Lite  ...          False
# 532                     Catholic Liturgical Calendar 2020  ...          False
# 546     Amplified Classic Bible + KJV & NIV Bibles, No...  ...          False
# 547                            Greek New Testament Reader  ...          False
# ...                                                   ...  ...            ...
# 141117                  AnalyzeQuran - Read & Study Quran  ...          False
# 141381                                       Sun and Moon  ...          False
# 141382                               Astronomical Almanac  ...          False
# 141578                                    Easy Study Tips  ...          False
# 141608                                    C++ Programming  ...          False
#
# [12276 rows x 23 columns]

# %%
#Count and display all Personalization category.
df[df["Category"] == "Personalization"]
# Out:
#                                                  App Name  ... Editors Choice
# 206              Castbox Locker: Bouncy Ball Player Theme  ...          False
# 384                                             Dark Mode  ...          False
# 395               Smart navigation bar - navbar slideshow  ...          False
# 397     Super Status Bar - Gestures, Notifications & more  ...          False
# 399                                             Glow kwgt  ...          False
# ...                                                   ...  ...            ...
# 139687                                Space Wallpapers HD  ...          False
# 139996                       Hippy Tie Dye Keyboard Theme  ...          False
# 140420                           Polyhedra Live Wallpaper  ...          False
# 140421                            Football Live Wallpaper  ...          False
# 141708                   Inspirational Life Lesson Quotes  ...          False
#
# [5687 rows x 23 columns]

# %%
#Count the values of all Ratings in ascending order.
df["Rating"].value_counts(dropna = False)
# Out:
# 0.0    26392
# 4.4    10330
# 4.5     9656
# 4.6     9558
# 4.3     9555
# 4.2     9076
# 4.7     7879
# 4.1     7265
# 4.0     6481
# 4.8     6118
# 3.9     5145
# 3.8     4666
# 3.7     3456
# 5.0     3451
# 4.9     3229
# 3.6     2791
# 3.5     2392
# 3.4     2023
# 3.3     1626
# 3.2     1492
# NaN     1416
# 3.1     1119
# 3.0     1098
# 2.9      816
# 2.8      756
# 2.7      605
# 2.6      547
# 2.5      442
# 2.4      406
# 2.3      351
# 2.2      304
# 2.1      244
# 2.0      241
# 1.9      189
# 1.8      163
# 1.7      105
# 1.6      100
# 1.5       79
# 1.4       57
# 1.0       32
# 1.2       27
# 1.3       25
# 1.1       11
# Name: Rating, dtype: int64

# %%
#Show the null value of Rating column
df["Rating"].isnull().sum()
# Out:
# 1416

# %%
#Fill null values with mean
df['Rating'].fillna((df['Rating'].mean()), inplace=True)

# %%
#Show 50 values of Rating
df.sort_values("Rating", ascending = False).head(15)
# Out:
#                                                  App Name  ... Editors Choice
# 83801                                            SOPASair  ...          False
# 22429   Monster Truck Racing: Monster Truck Shooting Game  ...          False
# 106866                                REI Employee Events  ...          False
# 128506   Emprendedor Millonario - Superación y Motivación  ...          False
# 88490                  BMI Calculator | Track Weight Loss  ...          False
# 64150                                                ورتل  ...          False
# 90852                                   UFC GYM Australia  ...          False
# 36308                      Santa Biblia Reina Valera 1960  ...          False
# 36297                      Estudios Biblicos para Jovenes  ...          False
# 117269                           Learn Korean - Beginners  ...          False
# 36290                      Reina Valera 1960 Santa Biblia  ...          False
# 46336                              جەژنی جولەكە وگاورەكان  ...          False
# 79513                                       GeliosTracker  ...          False
# 46333           چۆنێتى قوربانى كردن لەسەر دەمى پێغەمبەردا  ...          False
# 22383   Dragonfly Robot Transforming Games: Robot Car ...  ...          False
#
# [15 rows x 23 columns]

# %%
#Count the values of Rating Count.
df["Rating Count"].value_counts(dropna = False)
# Out:
# 0.0         26392
# 5.0          2470
# 6.0          2110
# 7.0          1820
# 8.0          1685
#             ...
# 337195.0        1
# 7165.0          1
# 6532.0          1
# 29265.0         1
# 81075.0         1
# Name: Rating Count, Length: 18474, dtype: int64

# %%
#fill Null values of Rating count with sum
df["Rating Count"].isnull().sum()
# Out:
# 1416

# %%
#df['Rating Count'].fillna((df['Rating'].mean()), inplace=True)

# %%
#Show top 15 values ofRating count
df.sort_values("Rating Count", ascending = False).head(15)
# Out:
#                                                 App Name  ... Editors Choice
# 42844                       Garena Free Fire: BOOYAH Day  ...           True
# 4975                                      Clash of Clans  ...           True
# 42846                           PUBG MOBILE METRO ROYALE  ...           True
# 11491                               Google Play services  ...          False
# 100605                         Mobile Legends: Bang Bang  ...          False
# 986                                       My Talking Tom  ...          False
# 16       Truecaller: Caller ID, block fraud & scam calls  ...          False
# 22454       Sniper 3D: Fun Free Online FPS Shooting Game  ...          False
# 1644                                             Hay Day  ...           True
# 42847                              Call of Duty®: Mobile  ...          False
# 2636                       Skype - free IM & video calls  ...           True
# 35                              Wish - Shopping Made Fun  ...          False
# 417     GO Launcher - 3D parallax Themes & HD Wallpapers  ...          False
# 38047                    VK — live chatting & free calls  ...          False
# 2632                       Opera Mini - fast web browser  ...          False
#
# [15 rows x 23 columns]

# %%
#Count the values of Installs
df["Installs"].value_counts(dropna = False)
# Out:
# 10,000+            26319
# 1,000+             22671
# 100,000+           18269
# 100+               14556
# 5,000+             11089
# 50,000+            10095
# 1,000,000+          8423
# 500+                8019
# 10+                 5553
# 500,000+            5540
# 50+                 4115
# 5,000,000+          2056
# 10,000,000+         1888
# 1+                  1176
# 5+                  1157
# 0+                   340
# 50,000,000+          230
# 100,000,000+         114
# NaN                   84
# 500,000,000+          11
# 1,000,000,000+         6
# 5,000,000,000+         2
# 10,000,000,000+        1
# Name: Installs, dtype: int64

# %%
#count null values 
df["Installs"].isnull().sum()
# Out:
# 84

# %%
#Fill null value with mean
df['Installs'].fillna((df['Installs'].mean), inplace=True)

# %%
#Replace "," with " " and "+" with ""
df["Installs"] = df["Installs"].str.replace(",","").str.replace("+","")
df["Installs"]
# Out:
# 0            100000
# 1           1000000
# 2          50000000
# 3         100000000
# 4             50000
#             ...
# 141709          100
# 141710          100
# 141711           50
# 141712        50000
# 141713          NaN
# Name: Installs, Length: 141714, dtype: object

# %%
#Count the free apps in dataset.
df["Free"].value_counts(dropna = False)
# Out:
# True     129633
# False     12080
# NaN           1
# Name: Free, dtype: int64

# %%
#Top 50 values 
df["Free"].head(50)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
# 5      True
# 6      True
# 7      True
# 8      True
# 9      True
# 10     True
# 11     True
# 12     True
# 13     True
# 14     True
# 15     True
# 16     True
# 17     True
# 18     True
# 19     True
# 20    False
# 21     True
# 22     True
# 23     True
# 24     True
# 25     True
# 26     True
# 27     True
# 28     True
# 29     True
# 30     True
# 31     True
# 32     True
# 33     True
# 34     True
# 35     True
# 36     True
# 37     True
# 38     True
# 39     True
# 40     True
# 41     True
# 42     True
# 43     True
# 44     True
# 45     True
# 46     True
# 47     True
# 48     True
# 49     True
# Name: Free, dtype: object

# %%
#Values count fo price 
df["Price"].value_counts(dropna = False)
# Out:
# 0.00     129716
# 0.99       2985
# 1.99       1666
# 2.99       1111
# 1.49       1004
#           ...
# 37.99         1
# 2.36          1
# 1.77          1
# 8.28          1
# 2.90          1
# Name: Price, Length: 332, dtype: int64

# %%
df["Price"].isnull().sum()
# Out:
# 1

# %%
#count the values that how much apps are released in same date
df["Released"].value_counts(dropna = False)
# Out:
# NaN             1645
# Jun 16, 2020     151
# May 21, 2019     130
# Aug 31, 2020     127
# Sep 17, 2020     127
#                 ...
# Mar 6, 2010        1
# Jun 19, 2010       1
# Sep 6, 2010        1
# May 23, 2010       1
# Aug 4, 2010        1
# Name: Released, Length: 3910, dtype: int64

# %%
df["Released"].isnull().sum()
# Out:
# 1645

# %%
#location of null values
df.loc[df['Released'].isnull()]
# Out:
#                                                  App Name  ... Editors Choice
# 27                          Docs To Go™ Free Office Suite  ...          False
# 56         GlucoMen Day CGM: Real-Time Glucose Monitoring  ...          False
# 61                                          Password Safe  ...          False
# 62                                       Memento Database  ...          False
# 131                                            PO Tracker  ...          False
# ...                                                   ...  ...            ...
# 140396  Protect Yourself - File, Message & Voice Encry...  ...          False
# 140456                             Timetable Neo Schedule  ...          False
# 140894                          AnyMemo: Flash Card Study  ...          False
# 141079                                   QuranHeroV2 Beta  ...          False
# 141713                             SpeedVPN Trade Edition  ...            NaN
#
# [1645 rows x 23 columns]

# %%
#counts the values that how much apps are last updates in same date
df["Last Updated"].value_counts(dropna = False)
# Out:
# Nov 25, 2020    1516
# Nov 24, 2020    1507
# Nov 26, 2020    1484
# Nov 23, 2020    1481
# Nov 27, 2020    1480
#                 ...
# Mar 01, 2012       1
# Jul 09, 2012       1
# Oct 30, 2011       1
# Feb 17, 2014       1
# NaN                1
# Name: Last Updated, Length: 3131, dtype: int64

# %%
#Show the content rating accordinf to the genre
df["Content Rating"].value_counts(dropna = False)
# Out:
# Everyone           121400
# Teen                12547
# Mature 17+           4018
# Everyone 10+         3732
# Adults only 18+        11
# Unrated                 5
# NaN                     1
# Name: Content Rating, dtype: int64

# %%
# top 20 content rating according to the genre
df["Content Rating"].head(20)
# Out:
# 0         Everyone
# 1     Everyone 10+
# 2         Everyone
# 3         Everyone
# 4         Everyone
# 5         Everyone
# 6         Everyone
# 7         Everyone
# 8         Everyone
# 9         Everyone
# 10        Everyone
# 11        Everyone
# 12        Everyone
# 13        Everyone
# 14        Everyone
# 15        Everyone
# 16        Everyone
# 17        Everyone
# 18        Everyone
# 19            Teen
# Name: Content Rating, dtype: object

# %%
#count the value of add supported apps
df["Ad Supported"].value_counts(dropna = False)
# Out:
# True     71123
# False    70590
# NaN          1
# Name: Ad Supported, dtype: int64

# %%
#count the value of in app purchase 
df["In App Purchases"].value_counts(dropna = False)
# Out:
# False    103022
# True      38691
# NaN           1
# Name: In App Purchases, dtype: int64

# %%
#count the value of editor choice
df["Editors Choice"].value_counts(dropna = False)
# Out:
# False    141462
# True        251
# NaN           1
# Name: Editors Choice, dtype: int64

# %% [markdown]
# # **Exploratory Data Analysis**
#
# ---

# %%
#Gives True when we give rnglish app name
def english(app_name):
    non_eng = 0
    for i in app_name:
        if(ord(i) > 127):
            non_eng += 1
            
    if(non_eng > 3):
        return False
    else:
        return True

# %%
#For checking purpose
english("!أوجد الكلمة")
# Out:
# False

# %%
#Apply English function on App Name
df["App Name"].apply(english)
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 141709    True
# 141710    True
# 141711    True
# 141712    True
# 141713    True
# Name: App Name, Length: 141714, dtype: bool

# %%
is_english = df["App Name"].apply(english)

# %%
#Sum of English App name
df["App Name"].apply(english).sum()
# Out:
# 126689

# %%
#Funal data after applyinh rng fuct
final_data = df[is_english].copy()

# %%
#Shape of data
final_data.shape
# Out:
# (126689, 23)

# %%
#Top 10 values of data(Only english app name)
pd.options.display.max_columns = None
final_data.head(10)
# Out:
#                                             App Name  \
# 0                             HTTrack Website Copier
# 1                      World War 2: Offline Strategy
# 2                                             WPSApp
# 3  OfficeSuite - Office, PDF, Word, Excel, PowerP...
# 4                                   Loud Player Free
# 5                                           eCharge+
# 6  Jobonji: hire local pros handyman for odd jobs...
# 7                          Little Panda’s Dream Town
# 8                            Baby Panda: Dental Care
# 9                                       Excel Reader
#
#                          App Id           Category  Rating  Rating Count  \
# 0           com.httrack.android      Communication     3.6        2848.0
# 1               com.skizze.wwii           Strategy     4.3       17297.0
# 2         com.themausoft.wpsapp              Tools     4.2      488639.0
# 3        com.mobisystems.office           Business     4.2     1224420.0
# 4      com.arthelion.loudplayer      Music & Audio     4.2         665.0
# 5            com.innogy.echarge  Maps & Navigation     3.5         377.0
# 6              com.pack.jobonji          Lifestyle     4.4        3346.0
# 7    com.sinyee.babybus.village        Educational     4.0       44700.0
# 8  com.sinyee.babybus.dentistII        Educational     4.1       10990.0
# 9          com.xcelfilereaderMS              Tools     3.3        1141.0
#
#     Installs  Minimum Installs  Maximum Installs  Free  Price Currency  Size  \
# 0     100000          100000.0          351560.0  True    0.0      USD  2.7M
# 1    1000000         1000000.0         2161778.0  True    0.0      USD   86M
# 2   50000000        50000000.0        79304739.0  True    0.0      USD  5.8M
# 3  100000000       100000000.0       163660067.0  True    0.0      USD   59M
# 4      50000           50000.0           73463.0  True    0.0      USD   29M
# 5      10000           10000.0           38029.0  True    0.0      USD   12M
# 6     100000          100000.0          224897.0  True    0.0      USD  9.4M
# 7   10000000        10000000.0        29969311.0  True    0.0      USD   90M
# 8   10000000        10000000.0        12520805.0  True    0.0      USD   87M
# 9     100000          100000.0          193274.0  True    0.0      USD  3.3M
#
#   Minimum Android                Developer Id  \
# 0      2.3 and up                Xavier Roche
# 1      5.1 and up                Skizze Games
# 2      4.1 and up                  TheMauSoft
# 3      4.4 and up                 MobiSystems
# 4      5.0 and up                 Arthelion92
# 5      6.0 and up  innogy eMobility Solutions
# 6      5.0 and up                Jobonji, Inc
# 7      4.2 and up                     BabyBus
# 8      4.2 and up                     BabyBus
# 9      5.0 and up              SphereLix Apps
#
#                  Developer Website  \
# 0          http://www.httrack.com/
# 1              http://stereo7.com/
# 2        http://www.themausoft.com
# 3       http://www.mobisystems.com
# 4         http://www.arthelion.com
# 5  http://www.innogy-emobility.com
# 6         https://www.jobonji.com/
# 7           http://www.babybus.com
# 8          https://www.babybus.com
# 9                              NaN
#
#                                Developer Email      Released  Last Updated  \
# 0                    roche+android@httrack.com  Aug 12, 2013  May 20, 2017
# 1                       Skizze.Games@gmail.com  Jul 19, 2018  Nov 26, 2020
# 2                         wpsapp.app@gmail.com   Mar 7, 2016  Oct 21, 2020
# 3  support-officesuite-android@mobisystems.com  Dec 22, 2011  Nov 23, 2020
# 4                        arthelion92@gmail.com  Sep 24, 2016  Nov 22, 2020
# 5                           echarge@innogy.com   Feb 4, 2019  Nov 06, 2020
# 6                          support@jobonji.com  Jan 10, 2018  Sep 30, 2019
# 7                              ser@babybus.com  Aug 16, 2018  Sep 29, 2020
# 8                      sinyeeandroid@gmail.com  Apr 27, 2020  Sep 29, 2020
# 9                    johnmarting6162@gmail.com  Jan 13, 2020  Jun 25, 2020
#
#   Content Rating                                     Privacy Policy  \
# 0       Everyone     http://android.httrack.com/privacy-policy.html
# 1   Everyone 10+     https://www.iubenda.com/privacy-policy/8032781
# 2       Everyone    https://sites.google.com/view/wpsapppolicy/main
# 3       Everyone  http://www.mobisystems.com/mobile/privacy-poli...
# 4       Everyone  http://www.arthelion.com/index.php/fr/android-...
# 5       Everyone  https://www.innogy.com/web/cms/en/3068482/home...
# 6       Everyone               https://www.jobonji.com/privacy.html
# 7       Everyone    http://en.babybus.com/index/privacyPolicy.shtml
# 8       Everyone    http://en.babybus.com/index/privacyPolicy.shtml
# 9       Everyone  https://docs.google.com/document/d/e/2PACX-1vS...
#
#   Ad Supported In App Purchases Editors Choice
# 0        False            False          False
# 1         True             True          False
# 2         True            False          False
# 3         True             True          False
# 4        False            False          False
# 5        False            False          False
# 6        False             True          False
# 7         True             True          False
# 8         True             True          False
# 9         True            False          False

# %%
#Drop the column
final_data.drop(["Free","Price"],axis = 1)
# Out:
#                                                  App Name  \
# 0                                  HTTrack Website Copier
# 1                           World War 2: Offline Strategy
# 2                                                  WPSApp
# 3       OfficeSuite - Office, PDF, Word, Excel, PowerP...
# 4                                        Loud Player Free
# ...                                                   ...
# 141709                    Psychology Facts For Life Hacks
# 141710                            Learn Civil Engineering
# 141711                             Learn Java Programming
# 141712                   Free CV Maker & Resume PDF Maker
# 141713                             SpeedVPN Trade Edition
#
#                                          App Id       Category    Rating  \
# 0                           com.httrack.android  Communication  3.600000
# 1                               com.skizze.wwii       Strategy  4.300000
# 2                         com.themausoft.wpsapp          Tools  4.200000
# 3                        com.mobisystems.office       Business  4.200000
# 4                      com.arthelion.loudplayer  Music & Audio  4.200000
# ...                                         ...            ...       ...
# 141709  studio.stovewestd.psychologyfactsoflife      Lifestyle  0.000000
# 141710  com.siringengvil.civilengineeringbasics      Education  0.000000
# 141711                 ab.hraor.javaprogarmming      Education  0.000000
# 141712            icv.sherskerapp.resumebuilder       Business  4.600000
# 141713                                        c            NaN  3.374484
#
#         Rating Count   Installs  Minimum Installs  Maximum Installs Currency  \
# 0             2848.0     100000          100000.0          351560.0      USD
# 1            17297.0    1000000         1000000.0         2161778.0      USD
# 2           488639.0   50000000        50000000.0        79304739.0      USD
# 3          1224420.0  100000000       100000000.0       163660067.0      USD
# 4              665.0      50000           50000.0           73463.0      USD
# ...              ...        ...               ...               ...      ...
# 141709           0.0        100             100.0             104.0      USD
# 141710           0.0        100             100.0             166.0      USD
# 141711           0.0         50              50.0              75.0      USD
# 141712         516.0      50000           50000.0           74201.0      USD
# 141713           NaN        NaN               NaN               NaN      NaN
#
#         Size Minimum Android          Developer Id  \
# 0       2.7M      2.3 and up          Xavier Roche
# 1        86M      5.1 and up          Skizze Games
# 2       5.8M      4.1 and up            TheMauSoft
# 3        59M      4.4 and up           MobiSystems
# 4        29M      5.0 and up           Arthelion92
# ...      ...             ...                   ...
# 141709  4.0M    4.0.3 and up  Powerful Study House
# 141710  2.3M    4.0.3 and up  Powerful Study House
# 141711  3.8M    2.3.3 and up  Powerful Study House
# 141712   13M      5.0 and up  Powerful Study House
# 141713   NaN             NaN                   NaN
#
#                         Developer Website  \
# 0                 http://www.httrack.com/
# 1                     http://stereo7.com/
# 2               http://www.themausoft.com
# 3              http://www.mobisystems.com
# 4                http://www.arthelion.com
# ...                                   ...
# 141709  https://w7be2eb99.app-ads-txt.com
# 141710  https://w7be2eb99.app-ads-txt.com
# 141711  https://w7be2eb99.app-ads-txt.com
# 141712  https://w7be2eb99.app-ads-txt.com
# 141713                                NaN
#
#                                     Developer Email      Released  \
# 0                         roche+android@httrack.com  Aug 12, 2013
# 1                            Skizze.Games@gmail.com  Jul 19, 2018
# 2                              wpsapp.app@gmail.com   Mar 7, 2016
# 3       support-officesuite-android@mobisystems.com  Dec 22, 2011
# 4                             arthelion92@gmail.com  Sep 24, 2016
# ...                                             ...           ...
# 141709                     powerofstudies@gmail.com   Jan 1, 2020
# 141710                     Powerofstudies@gmail.com  Sep 23, 2019
# 141711                     Powerofstudies@gmail.com  Sep 23, 2019
# 141712                     Powerofstudies@gmail.com   Dec 8, 2019
# 141713                                          NaN           NaN
#
#         Last Updated Content Rating  \
# 0       May 20, 2017       Everyone
# 1       Nov 26, 2020   Everyone 10+
# 2       Oct 21, 2020       Everyone
# 3       Nov 23, 2020       Everyone
# 4       Nov 22, 2020       Everyone
# ...              ...            ...
# 141709  Jan 01, 2020       Everyone
# 141710  Sep 23, 2019       Everyone
# 141711  Sep 23, 2019       Everyone
# 141712  Dec 08, 2019       Everyone
# 141713           NaN            NaN
#
#                                            Privacy Policy Ad Supported  \
# 0          http://android.httrack.com/privacy-policy.html        False
# 1          https://www.iubenda.com/privacy-policy/8032781         True
# 2         https://sites.google.com/view/wpsapppolicy/main         True
# 3       http://www.mobisystems.com/mobile/privacy-poli...         True
# 4       http://www.arthelion.com/index.php/fr/android-...        False
# ...                                                   ...          ...
# 141709  https://sites.google.com/view/powerful-study-h...         True
# 141710  https://sites.google.com/view/powerful-study-h...         True
# 141711  https://sites.google.com/view/powerful-study-h...         True
# 141712  https://sites.google.com/view/powerful-study-h...         True
# 141713                                                NaN          NaN
#
#        In App Purchases Editors Choice
# 0                 False          False
# 1                  True          False
# 2                 False          False
# 3                  True          False
# 4                 False          False
# ...                 ...            ...
# 141709            False          False
# 141710            False          False
# 141711            False          False
# 141712            False          False
# 141713              NaN            NaN
#
# [126689 rows x 21 columns]

# %%
#Count the Installs value of final data
final_data["Installs"].value_counts()
# Out:
# 10000          22953
# 1000           19929
# 100000         16294
# 100            13183
# 5000            9753
# 50000           8756
# 1000000         7958
# 500             7120
# 10              5105
# 500000          5103
# 50              3765
# 5000000         1994
# 10000000        1850
# 1               1097
# 5               1069
# 0                315
# 50000000         229
# 100000000        114
# 500000000         11
# 1000000000         6
# 5000000000         2
# 10000000000        1
# Name: Installs, dtype: int64

# %%
# Out:
# 0            100000
# 1           1000000
# 2          50000000
# 3         100000000
# 4             50000
#             ...
# 141709          100
# 141710          100
# 141711           50
# 141712        50000
# 141713          NaN
# Name: Installs, Length: 126689, dtype: object

# %%
#mean of Installed application according to the genre of category
cat_means = final_data.groupby("Category")["Installs"].mean()
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# <ipython-input-63-ceb7120219bb> in <module>()
#       1 #mean of Installed application according to the genre of category
# ----> 2 cat_means = final_data.groupby("Category")["Installs"].mean()
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in mean(self, numeric_only)
#    1396             "mean",
#    1397             alt=lambda x, axis: Series(x).mean(numeric_only=numeric_only),
# -> 1398             numeric_only=numeric_only,
#    1399         )
#    1400
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/groupby/groupby.py in _cython_agg_general(self, how, alt, numeric_only, min_count)
#    1051
#    1052         if len(output) == 0:
# -> 1053             raise DataError("No numeric types to aggregate")
#    1054
#    1055         return self._wrap_aggregated_output(output, index=self.grouper.result_index)
#
# DataError: No numeric types to aggregate

# %%
#show the mean
cat_means

# %%
#set the value in ascending order
sorted_cat = cat_means.sort_values(ascending = False)

# %%
sorted_cat

# %%
#Dsiplay all the entertainment category of english App name
com = final_data[final_data["Category"] == "Entertainment"]

# %%
com

# %%
#display top 30 English app name according to the installs
com[["App Name","Installs"]].sort_values("Installs",ascending = False).head(30)

# %%
#mean of install which is lesser than 100000000
com[com["Installs"] < 100000000]["Installs"].mean()

# %%
#Information of dataframe
com.info()

# %%
#Correaltion
com.corr()

# %%
plt.figure(figsize=(10,5))
ax=sns.heatmap(df.corr(),cmap="Set1",cbar=True,yticklabels=True,annot=True)
bottom,top=ax.get_ylim()
ax.set_ylim(bottom + 0.5,top -0.5)
plt.title('Correlation', fontdict={'size':20,'weight':'bold'})
plt.show()

# %%
sns.distplot(df["Rating"])
plt.show()

# %%
sns.distplot(df["Rating Count"])

# %%
fi = df.Category.str.split(', ', expand=True).stack().reset_index(level=1, drop=True)
za = cs.value_counts()[:20]
sa = ['red', 'purple', 'magenta', 'pink', 'orange','yellow', 'green', 'blue', 'brown', 'black',
       'grey', 'gold', 'turquoise', 'olive', 'maroon', 'teal', 'crimson', 'skyblue', 'violet', 'peru']


plt.figure(figsize=(20,10))
plt.title("Top 20 categories according to the installs", fontsize=20)
plt.xlabel("Intalls", fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel("Category", fontsize=20)
plt.barh(za.index, za.values, color=sa, align='center')
plt.show()

# %%
fii = df.Installs.str.split(', ', expand=True).stack().reset_index(level=1, drop=True)
zaa = cs.value_counts()[:10]
saa = ['red', 'purple', 'magenta', 'pink', 'orange','yellow', 'green', 'blue', 'brown', 'black']

plt.figure(figsize=(20,10))
plt.title("Top 10 installs according to the content Rating", fontsize=20)
plt.xlabel("Content Rating", fontsize=20)
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.ylabel("Installs", fontsize=20)
plt.barh(zaa.index, zaa.values, color=saa, align='center')
plt.show()

# %%
plt.figure(figsize=(20,10))
plt.title('Apps Rating', fontsize=14)
plt.pie(com.Rating.value_counts(), labels=com.Rating.value_counts().index, startangle=0, autopct='%1.1f%%')
plt.axis('equal')
my_circle=plt.Circle((0,0), 0.7, color='white')
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.show()

# %%
df2 = pd.DataFrame(columns = ['Category'])
df2["Category"]=[each for each in df.Category.unique()]
df2["Count"]=[len(df[df.Category==each]) for each in df2.Category]
df2=df2.sort_values(by=['Count'],ascending=False)

plt.figure(figsize=(25,15))
sns.barplot(x=df2.Category, y=df2.Count)
plt.xticks(rotation= 90)
plt.xlabel('Categorys', fontsize=20)
plt.ylabel('Count',fontsize=20)
plt.title('Categories according to the Count', fontdict={'size':20,'weight':'bold'})
plt.show()

# %%
df2 = pd.DataFrame(columns = ['Category'])
df2["Category"]=[each for each in df.Category.unique()]
df2["Ratings"]=[len(df[df.Category==each]) for each in df2.Category]
df2=df2.sort_values(by=['Ratings'],ascending=False)

plt.figure(figsize=(25,15))
sns.barplot(x=df2.Category, y=df2.Ratings)
plt.xticks(rotation= 90)
plt.xlabel('Categorys', fontsize=20)
plt.ylabel('Ratings', fontsize=20)
plt.title('Categories according to the Ratings', fontdict={'size':20,'weight':'bold'})
plt.show()

# %%
plt.pie(com.Free.value_counts(),radius=3,autopct='%0.2f%%',explode=[0.2,0.5],colors=['#00ffff','#00ff00'],labels=['Free','Not for Free'],
        startangle=90)

plt.title('Is App is Free?',fontdict={'size':20,'weight':'bold'})
plt.plot()

plt.show()

# %%
plt.pie(com['Ad Supported'].value_counts(),radius=3,autopct='%0.2f%%',explode=[0.2,0.1],colors=['#800080','#ff00ff'],labels=['Ad Supported','Ad not supported'],
        startangle=90)
plt.title('Is Ad supported?',fontdict={'size':20,'weight':'bold'})
plt.plot()

# %%
plt.pie(com['In App Purchases'].value_counts(),radius=3,autopct='%0.2f%%',explode=[0.2,0.2],colors=['#ffa500','#0000a0'],labels=['App not in purchase','App in purchase'],
        startangle=90)
plt.title('Is In App Purchases?',fontdict={'size':20,'weight':'bold'})
plt.plot()

# %%
#Drop The column
#com.drop(['App Id','Developer Website','Developer Email','Developer Id','Privacy Policy'],axis=1,inplace=True)
#com.head()

# %% [markdown]
# # **Machine Learning**
#
# ---
# ## **Multiple Regression**

# %%
#Training and testing the data
from sklearn.model_selection import train_test_split
train_data,test_data=train_test_split(com,test_size=0.15,random_state=42)

# %%
#Training the data
train_data.fillna(method='ffill',inplace=True)

# %%
train_data.isnull().sum()

# %%
train_data['Content Rating'].value_counts()

# %%
train_data.Free.value_counts()

# %%
train_data.shape,test_data.shape

# %%
train_data.info()

# %%
modification = train_data.drop(["App Name","Category","Ad Supported","In App Purchases","Editors Choice"],axis = 1)
modification

# %%
modification.drop(["Currency","Minimum Android","Released","Last Updated","Content Rating"],axis = 1,inplace = True)

# %%
#Replace everything with " "
modification["Size"] = modification["Size"].str.replace("M","").str.replace("Varies with device","7.8").str.replace("k","")

# %%
#Trasnfomr Function
def transform(val):
        if "M" in val:
            val = float(val.replace("M",""))
        elif "Varies with device" in val:
            val = float(val.replace("Varies with device","0"))
        elif "," in val:
            val = val.replace(",","")
        else:
            val = float(val.replace("K",""))
        return float(val)

# %%
modification["Size"] = modification["Size"].apply(transform)

# %%
#Testing the data
test_data.fillna(method='ffill',inplace=True)

# %%
test_data.isnull().sum()

# %%
test_data['Content Rating'].value_counts()
test_data.Free.value_counts()

# %%
modification2 = test_data.drop(["App Name","Category","Ad Supported","In App Purchases","Editors Choice"],axis = 1)
modification2

# %%
modification2.drop(["Currency","Minimum Android","Released","Last Updated","Content Rating"],axis = 1,inplace = True)

# %%
# modification2["Size"] = pd.to_numeric(modification2["Size"])
modification2['Size'].unique()

# %%
modification2["Size"] = modification2["Size"].str.replace(",","").str.replace("M","").str.replace("k","")
modification2["Size"].value_counts()

# %%
modification2['Size'].replace({'Varies with device':11.0},inplace = True)
modification2

# %%
frames = [modification,modification2]
result = pd.concat(frames)
result

# %%
result.drop(["Free","Price"],axis = 1, inplace = True)

# %%
result.reset_index()

# %%
#Normalization
normalized = result.iloc[:,:-1].div(result.iloc[:,:-1].sum(axis=1), axis=0)
normalized.iloc[::1,]

# %%
normalized["Rating"] = normalized["Rating"].astype(str)

# %%
#Imort Regex
import re
def split(val):
    req = re.search(r'^\d+',val)
    if req != None:
        return req.group(0)

# %%
normalized["Rating"] = normalized["Rating"].apply(split).astype(float)
normalized

# %%
normalized

# %%
np.isnan(normalized.any()) #and gets False
np.isfinite(normalized.all()) #and gets True

# %%
np.any(np.isnan(normalized))

# %%
np.all(np.isfinite(normalized))

# %%
normalized = normalized.dropna(axis=0, how='any')

# %%
normalized = normalized.reset_index()

# %%
normalized.isna().sum()

# %%
 normalized = normalized.replace([np.inf, -np.inf], np.nan)

# %%
normalized["Rating"].mean

# %%
normalized.columns

# %%
normalized["Rating"] = normalized["Rating"].replace(0.0,1)

# %%
normalized["Rating Count"] = normalized["Rating Count"].replace(0.0,1)

# %%
normalized["Rating Count"].replace(0.0,1)

# %%
np.isnan(normalized[['Rating', 'Rating Count', 'Installs', 'Minimum Installs','Maximum Installs']]).any()

# %%
normalized[normalized["Maximum Installs"] == 0.0]

# %%
normalized.dropna()

# %%
normalized.drop(["index"],axis = 1,inplace = True)

# %% [markdown]
# ## **Training and testing the data**
#
# ---

# %%
from sklearn.model_selection import train_test_split

X_train,X_test,y_train,y_test = train_test_split(normalized.iloc[:,:-1],
                                        normalized.iloc[:,-1],random_state = 0)

print("X TRAIN: {}".format(X_train.shape))
print("X TEST: {}".format(X_test.shape))
print("Y TRAIN: {}".format(y_train.shape))
print("Y TEST: {}".format(y_test.shape))

# %%
from sklearn.linear_model import LinearRegression

# %%
regression = LinearRegression()

regression.fit(X_train,y_train)
predicted = regression.predict(X_test)

# %%
 t_test = y_test.values.reshape(-1,1)

# %%
dfReg1 = pd.DataFrame({'Actual': t_test.flatten(), 'Predicted': predicted.flatten()})
dfReg1

# %%
#Accuracy
print("ACCURACY" ,regression.score(X_test,y_test))

# %%
top10=dfReg1.head(10)
top10.plot(kind='bar',figsize=(8,10))
plt.grid(which='major', linestyle='-', linewidth='0.3', color='green')
plt.grid(which='minor', linestyle=':', linewidth='0.5', color='black')
plt.show()

# %%
from sklearn import metrics
'Mean Absolute Error:', metrics.mean_absolute_error(t_test, predicted)

# %%
'Mean Squared Error:', metrics.mean_squared_error(t_test, predicted)

# %%
'Root Mean Squared Error:', np.sqrt(metrics.mean_squared_error(t_test,predicted))

# %%
import statsmodels.api as sm 
model = sm.OLS(predicted, X_test).fit()
predictions = model.predict(X_test)
model.summary()
